# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargamos uno de tus datasets para empezar el análisis
df = pd.read_csv('../data/raw/NHANES.csv')

# Vistazo rápido a los datos
print(df.info())
df.head()
